# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# Arrays
pre_nac = np.array([0.01056131, 0.01113949, 0.01030763, 0.01040128, 0.01038728,
                    0.0099591 , 0.01051326, 0.01049671, 0.01051185, 0.01013397,
                    0.00934412, 0.01043038, 0.01070072, 0.01018011, 0.01042813,
                    0.01057301, 0.01076779, 0.01047943, 0.01041362, 0.01051215])

pre_mca = np.array([0.00844376, 0.00872672, 0.00829277, 0.00834933, 0.00837677,
                    0.00842029, 0.00873207, 0.00842443, 0.00840377, 0.00830269,
                    0.00730255, 0.00839985, 0.00857473, 0.00841016, 0.0083555,
                    0.00828065, 0.00869923, 0.00829246, 0.00799245, 0.00845229])

pre_lhb = np.array([0.00564454, 0.00531705, 0.00584511, 0.00584979, 0.00594472,
                    0.00600811, 0.00619391, 0.00581469, 0.00585545, 0.00580774,
                    0.00595173, 0.00591232, 0.00576757, 0.00624433, 0.00578272,
                    0.00580592, 0.00595096, 0.00579633, 0.00582497, 0.00570309])

# Plot histograms
plt.figure(figsize=(10, 8))

plt.hist(pre_nac, bins=10, alpha=0.5, label='pre-nac', edgecolor='black')
plt.hist(pre_mca, bins=10, alpha=0.5, label='pre-mca', edgecolor='black')
plt.hist(pre_lhb, bins=10, alpha=0.5, label='pre-lhb', edgecolor='black')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histograms Bootstrap Values')
plt.legend()
plt.savefig('BootstrapHistValues.pdf')

# %%
np.savetxt('Prefrontal_nucleus_acumbens.txt',pre_nac,delimiter='\n',fmt='%0.8f')
np.savetxt('Prefrontal_mca.txt',pre_mca,delimiter='\n',fmt='%0.8f')
np.savetxt('Prefrontal_lhb.txt',pre_lhb,delimiter='\n',fmt='%0.8f')
