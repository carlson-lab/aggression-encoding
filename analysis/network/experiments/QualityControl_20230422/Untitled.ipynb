# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
import pandas as pd

import mat73
from data_tools import load_data

# %%
my_dict = mat73.loadmat('ESR1_data_all2.mat')

# %%
my_dict.keys()

# %%
features = load_data('ESR1_data_all2.mat')

# %%
features[0].shape

# %%
features[1].shape

# %%
features[2].shape

# %%
627/11
