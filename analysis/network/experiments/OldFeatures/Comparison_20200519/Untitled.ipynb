# %%
import matplotlib.pyplot as plt
import numpy as np
import pickle

# %%
pname = 'Trial1_best.p'
myDict = pickle.load(open(pname,'rb'))
myDict.keys()

# %%
losses_rec = myDict['losses_rec']
losses_sup = myDict['losses_sup']
losses_gen = myDict['losses_gen']

# %%
plt.plot(losses_rec)

# %%
plt.plot(losses_sup)

# %%
plt.plot(losses_gen)

# %%
print(losses_rec[0],losses_sup[0],losses_gen[0])
