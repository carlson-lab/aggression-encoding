# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
from scipy import io

# %%
myDict = pickle.load(open('Trial2_reweighted_true.p','rb'))
#myDict['recon_snmf_tr'] = 0.19290902
#myDict['recon_snmf_te'] = 0.14156331
#myDict = pickle.dump(myDict,open('Trial2_reweighted_true.p','wb'))

# %%
myDict['recon_snmf_tr']

# %%
myDict = io.loadmat('')
