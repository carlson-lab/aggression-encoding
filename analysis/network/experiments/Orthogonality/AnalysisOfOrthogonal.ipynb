# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import numpy.random as rand

# %%
myDict = pickle.load(open('Unbalanced_Orthogonal_12_enc_0.99.p','rb'))
myDict.keys()

# %%
S_train = myDict['S_train']
S_test = myDict['S_test']
A_enc = myDict['A_enc']

# %%
Phi = myDict['phi']
print(Phi)

# %%
y_hat = np.dot(S_train[:,:2],Phi)

# %%
plt.scatter(S_train[:,0],S_train[:,1],s=.01)

# %%
plt.scatter(S_train[:,0],S_train[:,2],s=.01)

# %%
plt.scatter(S_train[:,0],S_train[:,3],s=.01)

# %%
a = np.corrcoef(S_train.T)

# %%
b = np.corrcoef(A_enc.T)

# %%
b[:3,:3]

# %%
a[:3,:3]

# %%
a[:,:5]

# %%
b[:,:5]

# %%
A_enc.shape

# %%
1-.266

# %%
1-.285

# %%
np.mean(S_test[:,0]*.06)

# %%
np.mean(S_test[:,1]*.405)
