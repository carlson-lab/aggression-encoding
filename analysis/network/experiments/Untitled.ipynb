# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn.linear_model as lm
import pandas as pd

import mat73

# %%
my_dict = mat73.loadmat('TrainUrine_56HzPowerGrangerCoherenceLabels.mat')

# %%
import h5py
f = h5py.File('TrainUrine_56HzPowerGrangerCoherenceLabels.mat')

# %%
list(f.keys())

# %%
power = f['power'].value

# %%
type(power)

# %%
power.shape

# %%
coh = f['coherence'].value

# %%
coh.shape

# %%
g = f['granger'].value
